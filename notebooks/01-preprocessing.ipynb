# %% [markdown]
# # 01-preprocessing
#
# See plan/03-analysis-protocol.md for detailed protocol.

# %%
import sys
sys.path.insert(0, "../src")
import scanpy as sc
import numpy as np
import matplotlib.pyplot as plt
from sctda_plasticity import config
from sctda_plasticity.visualize import set_publication_style
set_publication_style()
# %matplotlib inline
